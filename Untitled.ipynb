# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import jellyfish

# %%
df = pd.read_csv("C:\GIT\Amlin\companylist (1).csv", encoding='utf-8')
df_a = pd.read_csv("C:\GIT\Amlin\clean_data3.csv", encoding='utf-8')

# %%
df.head()
# Out:
#   Symbol                                    Name LastSale   MarketCap  \
# 0    PIH  1347 Property Insurance Holdings, Inc.     7.05    42010005
# 1   FLWS                 1-800 FLOWERS.COM, Inc.     9.95   649552776
# 2   FCCY           1st Constitution Bancorp (NJ)    16.35   130526857
# 3   SRCE                  1st Source Corporation    46.79  1210726436
# 4   VNET                    21Vianet Group, Inc.     7.04   406559704
#
#     ADR TSO IPOyear             Sector  \
# 0       n/a    2014            Finance
# 1       n/a    1999  Consumer Services
# 2       n/a     n/a            Finance
# 3       n/a     n/a            Finance
# 4  57749958    2011         Technology
#
#                                           Industry  \
# 0                       Property-Casualty Insurers
# 1                           Other Specialty Stores
# 2                             Savings Institutions
# 3                                      Major Banks
# ...

# %%
df_a.head()
# Out:
#    Day      Month  Year                         Company              City  \
# 0   21    October  2009   Bullitt County Public Schools    Shepherdsville
# 1   21    October  2009  Roane State Community College           Harriman
# 2   15    October  2009                  Halifax Health     Daytona Beach
# 3    4    October  2009       Suffolk Community College            Selden
# 4   28  September  2009                Penrose Hospital  Colorado Springs
#
#         State Type of breach Type of organization Records Breached  \
# 0    Kentucky           DISC                  EDU              676
# 1   Tennessee           PORT                  EDU            14783
# 2     Florida           PORT                  MED            33000
# 3    New York           DISC                  EDU              300
# 4    Colorado           PHYS                  MED              175
#
#    Total Records                            Description of incident
# ...

# %%
def get_closest_match(x, list_strings):

    best_match = None
    highest_jw = 0

    for current_string in list_strings:
        current_score = jellyfish.jaro_winkler(x, current_string)

    if(current_score > highest_jw):
        highest_jw = current_score
        best_match = current_string
    
    if highest_jw > 0.9:
        return best_match

# %%
df_a['Company_Names'] = df_a.Company.map(lambda x: get_closest_match(x, df.Name))
df_a['Score'] = get_closest_match(highest_jw)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-c73aea1a14e2> in <module>()
#       1 df_a['Company_Names'] = df_a.Company.map(lambda x: get_closest_match(x, df.Name))
# ----> 2 df_a['Score'] = get_closest_match(highest_jw)
#
# NameError: name 'highest_jw' is not defined

# %%
df1 = df_a[['Company', 'Company_Names']]
df1
# Out:
#                                                 Company  \
# 0                         Bullitt County Public Schools
# 1                        Roane State Community College
# 2                                        Halifax Health
# 3                             Suffolk Community College
# 4                                      Penrose Hospital
# 5                           Eastern Kentucky University
# 6                              Bernard Madoff Investors
# 7           Sagebrush Medical Plaza/Kern Medical Center
# 8                                   Rocky Mountain Bank
# 9                         University of Florida
# 10                 Jones General Store/Root of the Hill
# 11            Bluegrass Community and Technical College
# 12                             Naval Hospital Pensacola
# 13                          University of Massachusetts
# 14                         Northern Kentucky University
# 15                           Calhoun Area Career Center
# ...

# %%
 jellyfish.jaro_winkler(x, current_string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-0a9a70358cfe> in <module>()
# ----> 1 current_score = jellyfish.jaro_winkler(x, current_string)
#
# NameError: name 'x' is not defined
